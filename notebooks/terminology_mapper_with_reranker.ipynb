# %%
# %cd c:\Users\almei\Documents\GitHub\precision-data
from pathlib import Path
from aatm.translators import EmptyTranslator
from aatm.terminology_mapper import TerminologyMapper
from aatm.retrievers import CHROMADB_RETRIEVER_MODEL_REGISTRY as model_registry
from aatm.retrievers import load_chromadb_retriever
from aatm.selectors import FirstResultSelector
from aatm.rerankers import load_reranker

model_name = "text-embedding-3-small"
reranker_name = "Qwen/Qwen3-Reranker-4B"

# translator = AsyncGeminiTranslator(model="gemini-2.5-flash")
translator = EmptyTranslator()
retriever = load_chromadb_retriever(model_name)
selector = FirstResultSelector()
reranker = load_reranker(reranker_name)

tm = TerminologyMapper(
    translator=translator,
    retriever=retriever,
    selector=selector, 
    reranker=reranker,
    batch_size=10,
    rate_limit=model_registry[model_name].get("rate_limit"),
    output_dir=Path(model_registry[model_name]["output_path"])/"with-reranker"/reranker_name,
)

mapped_concepts_df = tm.map(
    'vocabularies/SOURCE_TO_CONCEPT_MAP.csv',
)
# Out:
# c:\Users\almei\Documents\GitHub\precision-data
# c:\Users\almei\Documents\GitHub\precision-data\.venv\Lib\site-packages\torch\cuda\__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# There are 16 null values in the source_code_description column. Those rows will be dropped.
# Dropped rows: [7, 169, 262, 354, 369, 370, 390, 391, 393, 403, 494, 583, 840, 938, 1003, 1056]
# Mapping source concepts (batch_size = 10):   0%|          | 0/145 [00:00<?, ?it/s]c:\Users\almei\Documents\GitHub\precision-data\.venv\Lib\site-packages\transformers\tokenization_utils_base.py:2402: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# Mapping source concepts (batch_size = 10): 100%|██████████| 145/145 [04:29<00:00,  1.86s/it]
