# %%
# %cd c:\Users\almei\Documents\GitHub\precision-data
import chromadb
import dotenv

from aatm.retrievers import load_chromadb_retriever
from aatm.translators import GeminiTranslator
from aatm.selectors import load_selector


dotenv.load_dotenv()

retriever_name = 'text-embedding-3-large'
selector_name = 'gpt-5.2'

client = chromadb.PersistentClient()
translator = GeminiTranslator(model='gemini-2.5-flash')
retriever = load_chromadb_retriever(retriever_name)
selector = load_selector(selector_name)
# Out:
# c:\Users\almei\Documents\GitHub\precision-data
# c:\Users\almei\Documents\GitHub\precision-data\.venv\Lib\site-packages\torch\cuda\__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-02-05 00:21:38 | INFO     | chromadb.telemetry.product.posthog:22 | Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2026-02-05 00:21:38 | INFO     | chromadb.telemetry.product.posthog:22 | Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.

# %%
results = ["dor torácica"]  | retriever | selector
for idx, result in enumerate(results.results):
    print(f"{idx+1} - {result}")
    print()
# Out:
# 2026-02-05 00:27:53 | INFO     | httpx:1025 | HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-02-05 00:27:53 | DEBUG    | aatm.selectors:105 | [{'role': 'system', 'content': 'Select the expression from the list of expressions that is semantically closest to the query. You are mapping a non-standard concept to a standard concept and the list of expressions are already mapped to standard concepts. Your response should be a JSON object and include the expression_id of the selected expression. If no expression matches the query, return \'{"expression_id": null}\'.\n\nJSON object format: {\'properties\': {\'expression_id\': {\'anyOf\': [{\'type\': \'string\'}, {\'type\': \'null\'}], \'default\': None, \'title\': \'Expression Id\'}}, \'title\': \'SelectedResult\', \'type\': \'object\'}'}, {'role': 'user', 'content': "Query: dor torácica\n\nExpressions: [{'expression_id': '9b410c9ffb0a3ba7a1dd91ef687f3e0f', 'expression': 'dolor torácico localizado', 'standard_concept_name': 'Localized chest pain', 'standard_vocabulary_id': 'SNOMED', 'standard_vocabulary_code': '97001000119106', 'standard_domain_id': 'Condition'}, {'expression_id': '8928f9592e5e520b7734cf31fbacfdb3', 'expression': 'dorsalgia torácica', 'standard_concept_name': 'Thoracic back pain', 'standard_vocabulary_id': 'SNOMED', 'standard_vocabulary_code': '279038004', 'standard_domain_id': 'Condition'}, {'expression_id': '5bf8612a4954e5daa0f2062f0feed6a5', 'expression': 'dolor torácico no cardíaco', 'standard_concept_name': 'Non-cardiac chest pain', 'standard_vocabulary_id': 'SNOMED', 'standard_vocabulary_code': '274668005', 'standard_domain_id': 'Condition'}, {'expression_id': 'e623546f1cc35386b434730ceff5f836', 'expression': 'dolor torácico superior', 'standard_concept_name': 'Upper chest pain', 'standard_vocabulary_id': 'SNOMED', 'standard_vocabulary_code': '285389008', 'standard_domain_id': 'Condition'}, {'expression_id': '01263520126602eaac203d0e563864b3', 'expression': 'dolor torácico central', 'standard_concept_name': 'Central chest pain', 'standard_vocabulary_id': 'SNOMED', 'standard_vocabulary_code': '161972006', 'standard_domain_id': 'Condition'}, {'expression_id': '00e2f21e37584c1ac6aa66e2e6318ff4', 'expression': 'malestar torácico', 'standard_concept_name': 'Chest discomfort', 'standard_vocabulary_id': 'SNOMED', 'standard_vocabulary_code': '279084009', 'standard_domain_id': 'Condition'}, {'expression_id': 'f5b499fcaaa77c0ce7b2251ed42822dd', 'expression': 'dolor torácico crónico', 'standard_concept_name': 'Chronic chest pain', 'standard_vocabulary_id': 'SNOMED', 'standard_vocabulary_code': '434011000124101', 'standard_domain_id': 'Condition'}, {'expression_id': '5ef22e907c5a1639a9054342280df738', 'expression': 'dolor torácico musculoesquelético', 'standard_concept_name': 'Musculoskeletal chest pain', 'standard_vocabulary_id': 'SNOMED', 'standard_vocabulary_code': '281245003', 'standard_domain_id': 'Condition'}, {'expression_id': '6e79d4e8142aeb292120ed372e1c4de7', 'expression': 'dolor radicular torácico', 'standard_concept_name': 'Thoracic nerve root pain', 'standard_vocabulary_id': 'SNOMED', 'standard_vocabulary_code': '103015000', 'standard_domain_id': 'Condition'}, {'expression_id': 'd8dddb4d26256ccc0a9ac55396486e43', 'expression': 'dolor torácico pleuropericárdico', 'standard_concept_name': 'Pleuropericardial chest pain', 'standard_vocabulary_id': 'SNOMED', 'standard_vocabulary_code': '13057000', 'standard_domain_id': 'Condition'}]"}]
# 2026-02-05 00:27:56 | INFO     | httpx:1025 | HTTP Request: POST https://api.openai.com/v1/responses "HTTP/1.1 200 OK"
# 2026-02-05 00:27:56 | DEBUG    | aatm.selectors:114 | ParsedResponse[SelectedResult](id='resp_06d4261263d75fcd0069840e3b3750819f8654e9aca3abc531', created_at=1770262075.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.2-2025-12-11', object='response', output=[ParsedResponseOutputMessage[SelectedResult](id='msg_06d4261263d75fcd0069840e3bf178819f920b29514e24bebf', content=[ParsedResponseOutputText[SelectedResult](annotations=[], text='{"expression_id":"9b410c9ffb0a3ba7a1dd91ef687f3e0f"}', type='output_text', logprobs=[], parsed=SelectedResult(expression_id='9b410c9ffb0a3ba7a1dd91ef687f3e0f'))], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=0.98, background=False, completed_at=1770262076.0, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='SelectedResult', schema_={'properties': {'expression_id': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'title': 'Expression Id'}}, 'title': 'SelectedResult', 'type': 'object', 'additionalProperties': False, 'required': ['expression_id']}, type='json_schema', description=None, strict=True), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=982, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=36, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=1018), user=None, billing={'payer': 'developer'}, frequency_penalty=0.0, presence_penalty=0.0, store=True)
# 2026-02-05 00:27:56 | DEBUG    | aatm.selectors:115 | expression_id='9b410c9ffb0a3ba7a1dd91ef687f3e0f'
# 1 - expression_id='9b410c9ffb0a3ba7a1dd91ef687f3e0f' expression='dolor torácico localizado' expression_concept_id='43021837' expression_origin=<ExpressionOrigin.STANDARD_CONCEPT_SYNONYM: 'standard_concept_synonym'> std_concept_id='43021837' std_concept_name='Localized chest pain' std_vocabulary_id=<StandardVocabulary.SNOMED: 'SNOMED'> std_vocabulary_code='97001000119106' std_domain_id='Condition' distance=0.4775431454181671 rerank_score=None result_list_index=0
