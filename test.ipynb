# %%
import gdown

url = "https://drive.google.com/file/d/1vwnhH56KZssGCp2MVV0m0iTEQ2gYTHuy/view?usp=sharing"
gdown.download(url=url, output="vector_database.zip", fuzzy=True, quiet=True)
# Out:
# 'vector_database.zip'
