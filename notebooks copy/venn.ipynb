# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Your provided data
data = {
  "problem_list": [
    "rayyan-216121950", "rayyan-166327941", "rayyan-166327947", "rayyan-166327984",
    "rayyan-166328009", "rayyan-166328118", "rayyan-166328120", "rayyan-166328123",
    "rayyan-166328125", "rayyan-166328146", "rayyan-166328151", "rayyan-166328286",
    "rayyan-166328461", "rayyan-166329190", "rayyan-166329463", "rayyan-166329560",
    "rayyan-166329569", "rayyan-166329573", "rayyan-166329582", "rayyan-166329592",
    "rayyan-166329771", "rayyan-166329859", "rayyan-166330067", "rayyan-166330223",
    "rayyan-166330272", "rayyan-166330423", "rayyan-166330487", "rayyan-166330574",
    "rayyan-166330579", "rayyan-166330693", "rayyan-166330714", "rayyan-166330793",
    "rayyan-166330798", "rayyan-166330889", "rayyan-166330911", "rayyan-166330933", "rayyan-166330797"
  ],
  "soap": [
    "rayyan-166327941", "rayyan-166328009", "rayyan-166328125", "rayyan-166328151",
    "rayyan-166328560", "rayyan-166329771", "rayyan-166329859", "rayyan-166330067",
    "rayyan-166330423", "rayyan-166330487"
  ],
  "episode_of_care": [
    "rayyan-166327941", "rayyan-166328009", "rayyan-166328286", "rayyan-166329771",
    "rayyan-166330423", "rayyan-166330487", "rayyan-166330798"
  ]
}

# Convert lists to sets for Venn diagram plotting
set_problem_list = set(data["problem_list"])
set_soap = set(data["soap"])
set_episode = set(data["episode_of_care"])

# Create the plot
plt.figure(figsize=(10, 8), dpi=1000)
venn = venn3(
    subsets=[set_problem_list, set_soap, set_episode], 
    set_labels=('Problem List', 'SOAP', 'Episode of Care'),
    set_colors=('#8A7650', '#8E977D', '#ECE7D1'),
    alpha=0.85
)

plt.show()

# %%
a = set(["rayyan-166328286",
"rayyan-166330889",
"rayyan-166328560",
"rayyan-166329573",
"rayyan-166330579",
"rayyan-166330487",
"rayyan-166328123",
"rayyan-166330423",
"rayyan-166327941",
"rayyan-166329560",
"rayyan-166329569",
"rayyan-166329592",
"rayyan-166330693",
"rayyan-166328118",
"rayyan-166330714",
"rayyan-166328146",
"rayyan-166329190",
"rayyan-166330272",
"rayyan-166328125",
"rayyan-166330067",
"rayyan-216121950",
"rayyan-166330933",
"rayyan-166329771",
"rayyan-166330223",
"rayyan-166328151",
"rayyan-166330793",
"rayyan-166329859",
"rayyan-166330911",
"rayyan-166330798",
"rayyan-166330797",
"rayyan-166328120",
"rayyan-166329582",
"rayyan-166330574",
"rayyan-166329463",
"rayyan-166327984",
"rayyan-166328461",
"rayyan-166328009",
"rayyan-166327947"])
len(a)
# Out:
# 38

# %%
a - set_problem_list - set_soap - set_episode
# Out:
# {'rayyan-166330797'}
