# %%
# %cd ..
# Out:
# c:\Users\almei\Documents\GitHub\aatm

# %%
from aatm.terminology_mapper import TerminologyMapper

tm = TerminologyMapper(
    translator="gemini-2.5-flash",
    retriever="embeddinggemma-300M",
    selector="first-result-selector",
)
# Out:
# c:\Users\almei\Documents\GitHub\aatm\.venv\Lib\site-packages\torch\cuda\__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Loading weights:   0%|          | 0/314 [00:00<?, ?it/s]

# %%
tm.map(['encaminhamento para um cardiologista'])
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#   source_code source_concept_id source_vocabulary_id  \
# 0        None              None                 None
#
#       source_code_description valid_start_date valid_end_date invalid_reason  \
# 0  referral to a cardiologist             None           None           None
#
#   target_concept_id target_vocabulary_id target_vocabulary_code    domain_id  \
# 0           4204664               SNOMED              308471005  Observation
#
#    confidence_score      source_code_description_original
# 0          0.925329  encaminhamento para um cardiologista
